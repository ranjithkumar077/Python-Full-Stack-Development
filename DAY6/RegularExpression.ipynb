# %% [markdown]
# # Regular Expression

# %%
import re

sentence="today is 25-04-2026 and tomorrow is 26-04-2026"
pattern=r"[0-9]{2}-[0-9]{2}-[0-9]{4}"
date =re.findall(pattern,sentence)
print(date)
# Out:
# ['25-04-2026', '26-04-2026']

# %% [markdown]
# # Email Validation

# %%
import re 

def is_valid_email(email):
    pattern=r'^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}$'
    return re.fullmatch(pattern,email) is not None

# email=input(" Enter your email address")

print(is_valid_email("test@example.com"))   
print(is_valid_email("bad-email@com"))      
print(is_valid_email("user@domain.co.in"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       5     return re.fullmatch(pattern,email) is not None
#       6
#       7 email=input(" Enter your email address")
#       8
# ----> 9 print(is_valid_email())
#      10 # print(is_valid_email("bad-email@com"))
#      11 # print(is_valid_email("user@domain.co.in"))
#
# TypeError: is_valid_email() missing 1 required positional argument: 'email'
