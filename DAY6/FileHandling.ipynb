# %% [markdown]
# # File Handling

# %%
#opening the file and reading the file 
#syntax = f=open(path,mode)
file_rep=open("file.txt","r")
file_data=file_rep.read()
print(file_data)
# Out:
# Good morning Fellow!
# i am ranjith kumar
# and i am from kuppam

# %%
#append
# 
    with open("file.txt", "a") as f:
        f.write(" i am the King")
        f.close

# %%
# Write 
# over write the data when the file contains data 
with open("data1.txt","w") as e:
    e.write("\n king Slayer")
    e.close()

# %%
# Create a new file 
with open("data2.text","x") as x:
    x.write(" i am new file")

# %%
# To Handle the file not found error
try:
    with open("data1.txt", "x") as x:
        x.write("I am new file")
except FileExistsError:
    print("File already exists!")
except Exception as e:
    print("Error",e)
# Out:
# File already exists!
