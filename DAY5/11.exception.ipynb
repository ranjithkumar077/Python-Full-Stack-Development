# %% [markdown]
# Exception in Python

# %%
# Type of Exception:
# 1. SyntaxError
# 2.  logical error
# 3.  Runtime error


#1 SyntaxError
print("hello world)# missing the double quotes 
#2 logical error 
def add(a,b)
    return a_b
add

# %%
# division 
try:
    a =int(input("enter the number "))#41
    b =int(input("enter the number "))#0
    c=a/b
    print(c)
except Exception as e:
    print(" ERROR",e)
except ValueError as v:
    print(v)
else:
    print("c")
finally:
    (" done ")

# error occur when a number divisible by the 0 
# to handle this Exception 
#
# Out:
# 3.0
# c

# %%
user_num =int(input(" give a number"))
try:
    if user_num<0:
        raise Exception("ERROR ")# raise is to use customize the Error or Exception msg
    else:
        print(user_num)
except Exception as e:
    print(e)
# Out:
# ERROR
